# %% [markdown]
# # Day 1: Session 1B - Python Essentials
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/1b_python_essentials.html)
#
# Date: 08/31/2026

# %%
temperature = 21

# %%
site_name = "Santa Barbara"

# %%
temperature
# Out:
# 21

# %%
high_temp = 24
low_temp = 12

temp_range = high_temp - low_temp

# %%
morning_temp = 78
afternooon_temp = 88

daily_swing = afternooon_temp - morning_temp

daily_swing
# Out:
# 10

# %%
description = """

This dataset records daily air temperature at
three stations. 

    Its great

"""

# %%
count = 42          # an int
rainfall = 3.5      # a float

# %%
type(count)
# Out:
# int

# %%
type(rainfall)
# Out:
# float

# %%
type(site_name)
# Out:
# str

# %%
type(description)
type(rainfall)
# Out:
# float

# %%
description.lower()
# Out:
# '\n\nthis dataset records daily air temperature at\nthree stations. \n\nits great\n\n'

# %%
"3".isdigit()
# Out:
# True

# %%
count.to_bytes()
# Out:
# b'*'

# %%
# this is so we can see both outputs in the
# same code chunk
print(type(description))
print(type(rainfall))
print("I love to Code")
# Out:
# <class 'str'>
# <class 'float'>
# I love to Code

# %%
name = "Alice"
print(f"Hello, {name}!") # this is calling the name object
# Out:
# Hello, Alice!

# %%
print(f"The low was {low_temp}, and the high temp was {high_temp}. So the difference in themperature was {temp_range}")
# Out:
# The low was 12, and the high temp was 24. So the difference in themperature was 12

# %%
station = "CNSI Roof Top"
readings = 30
warmest = 27

# %%
print(f"The station is {station}.")
print(f"It logged {readings} readings today.")
print(f"The warmest reading was {warmest} degrees.")
# Out:
# The station is CNSI Roof Top.
# It logged 30 readings today.
# The warmest reading was 27 degrees.

# %%
site = "Santa Barbara"
day1_rain_mm = 5
day2_rain_mm = 0
day3_rain_mm = 7

n_days = 3
total_rain_mm = day1_rain_mm + day2_rain_mm + day3_rain_mm   # daily rainfall adds up to a total
average_rain_mm = total_rain_mm / n_days

# %%
print(f"We tracked rainfall in {site} for {n_days}")
print(f"In total, there was {total_rain_mm} mm within the {n_days} days")
# Out:
# We tracked rainfall in Santa Barbara for 3
# In total, there was 12 mm within the 3 days
