# %% [markdown]
# # Day 6: Session 6C - A Date Is Not a Number
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/6c_dates.html)
#
# Date: 09/08/2026

# %%
import pandas as pd

url = 'https://eds-217-essential-python.github.io/data/toolik_weather.csv'
toolik = pd.read_csv(url)

# keeping only these columns
toolik[['Year', 'Month', 'Date', 'Daily_AirTemp_Mean_C']].head()
# Out:
#    Year  Month      Date  Daily_AirTemp_Mean_C
# 0  1988      6  19880601                   8.4
# 1  1988      6  19880602                   6.0
# 2  1988      6  19880603                   5.8
# 3  1988      6  19880604                   1.8
# 4  1988      6  19880605                   6.8

# %%
toolik['Date'].dtype
# Out:
# dtype('int64')

# %%
toolik['date'] = pd.to_datetime(toolik['Date'], format = '%Y%m%d')

toolik[['Date', 'date']].head()
# Out:
#        Date       date
# 0  19880601 1988-06-01
# 1  19880602 1988-06-02
# 2  19880603 1988-06-03
# 3  19880604 1988-06-04
# 4  19880605 1988-06-05

# %% [markdown]
# pd.to_datetime(column, format='%Y%m%d')
# ####     /////////////         ↑         //////////        ↑
# ####    /////////////         what to parse  //////// how it is laid out

# %%
url2 = 'https://eds-217-essential-python.github.io/data/date_data.csv'
date = pd.read_csv(url2)

date.head()
# Out:
#          Date  Value Category
# 0  2023-11-02  19.51        A
# 1  2022-05-25  41.51        B
# 2  2021-10-05  70.52        C
# 3  2023-07-16   7.61        A
# 4  2021-01-08  30.93        C

# %%
print(toolik['date'].dtype)
print(toolik['date'].min())
print(toolik['date'].max())
# Out:
# datetime64[ns]
# 1988-06-01 00:00:00
# 2018-12-31 00:00:00

# %%
toolik['year'] = toolik['date'].dt.year
toolik['month'] = toolik['date'].dt.month
toolik['day'] = toolik['date'].dt.day

toolik[['date', 'year', 'month', 'day']].head()
# Out:
#         date  year  month  day
# 0 1988-06-01  1988      6    1
# 1 1988-06-02  1988      6    2
# 2 1988-06-03  1988      6    3
# 3 1988-06-04  1988      6    4
# 4 1988-06-05  1988      6    5

# %%
toolik['dayofyear'] = toolik['date'].dt.dayofyear

# these are the leap years
toolik[toolik['dayofyear'] == 366]
# Out:
#        Year  Month      Date LTER_Site  Station  Daily_AirTemp_Mean_C  \
# 213    1988     12  19881231       ARC  TLKMAIN                  -8.6
# 1674   1992     12  19921231       ARC  TLKMAIN                  -5.3
# 3135   1996     12  19961231       ARC  TLKMAIN                 -26.8
# 4596   2000     12  20001231       ARC  TLKMAIN                 -30.5
# 6057   2004     12  20041231       ARC  TLKMAIN                  -6.7
# 7518   2008     12  20081231       ARC  TLKMAIN                 -25.4
# 8979   2012     12  20121231       ARC  TLKMAIN                 -26.2
# 10440  2016     12  20161231       ARC  TLKMAIN                  -6.1
#
#       Flag_Daily_AirTemp_Mean_C  Daily_AirTemp_AbsMax_C  \
# 213                         NaN                    -6.5
# 1674                        NaN                    -1.5
# 3135                        NaN                   -22.8
# 4596                          E                   -28.6
# 6057                        NaN                    -1.1
# 7518                        NaN                   -21.5
# 8979                          E                   -19.4
# 10440                       NaN                    -1.5
#
#       Flag_Daily_AirTemp_AbsMax_C  Daily_AirTemp_AbsMin_C  ...  \
# 213                           NaN                   -10.7  ...
# 1674                          NaN                    -8.1  ...
# 3135                          NaN                   -32.0  ...
# 4596                            E                   -34.2  ...
# 6057                          NaN                   -13.4  ...
# 7518                          NaN                   -28.7  ...
# 8979                            E                   -29.8  ...
# 10440                         NaN                   -10.9  ...
#
#       Daily_globalrad_total_jcm2  FLAG_Daily_globalrad_total_mjm2 Moss  \
# 213                          NaN                              NaN -6.0
# 1674                         NaN                              NaN -7.0
# 3135                         NaN                              NaN -7.0
# 4596                         NaN                              NaN  NaN
# 6057                         NaN                              NaN -8.0
# 7518                        19.0                              NaN -8.0
# 8979                         NaN                              NaN -7.0
# 10440                        NaN                              NaN -3.0
#
#        Soil20cm                                           Comments       date  \
# 213        -5.0          Using Imnavait SNOTEL precipitation data. 1988-12-31
# 1674       -7.0          Using Imnavait SNOTEL precipitation data. 1992-12-31
# 3135       -6.0          Using Imnavait SNOTEL precipitation data. 1996-12-31
# 4596        NaN  Data logger stopped during winter, 24Nov2000 t... 2000-12-31
# 6057       -6.0                                                  0 2004-12-31
# 7518       -6.0          Using Imnavait SNOTEL precipitation data. 2008-12-31
# 8979       -6.0          Using Imnavait SNOTEL precipitation data. 2012-12-31
# 10440      -4.0                                                NaN 2016-12-31
#
#        year month  day  dayofyear
# 213    1988    12   31        366
# 1674   1992    12   31        366
# 3135   1996    12   31        366
# 4596   2000    12   31        366
# 6057   2004    12   31        366
# 7518   2008    12   31        366
# 8979   2012    12   31        366
# 10440  2016    12   31        366
#
# [8 rows x 26 columns]

# %%
toolik.groupby('month')['Daily_AirTemp_Mean_C'].mean().round(2)
# Out:
# month
# 1    -22.89
# 2    -20.70
# 3    -20.69
# 4    -11.76
# 5     -0.80
# 6      8.59
# 7     11.22
# 8      7.23
# 9     -0.11
# 10   -10.54
# 11   -18.34
# 12   -21.44
# Name: Daily_AirTemp_Mean_C, dtype: float64

# %%
toolik.groupby('year')['Daily_AirTemp_Mean_C'].agg(['count', 'mean']).head(3).round(2)
# Out:
#       count  mean
# year
# 1988    214 -4.88
# 1989    365 -7.94
# 1990    365 -8.54

# %%
early = toolik[toolik['year'] <= 1998]
late = toolik[toolik['year'] >= 2009]

print(early.shape)
print(late.shape)
# Out:
# (3866, 26)
# (3652, 26)

# %%
comparison = pd.DataFrame({
    'early' : early.groupby('month')['Daily_AirTemp_Mean_C'].mean(),
    'late' : late.groupby('month')['Daily_AirTemp_Mean_C'].mean()
})

comparison['change'] = comparison['late'] - comparison['early']

comparison.round(2)
# Out:
#        early   late  change
# month
# 1     -24.72 -21.26    3.46
# 2     -21.86 -19.38    2.48
# 3     -18.62 -20.64   -2.02
# 4     -10.40 -11.86   -1.45
# 5       0.37  -0.54   -0.91
# 6       8.43   8.19   -0.24
# 7      12.05  11.28   -0.77
# 8       7.48   7.18   -0.30
# 9      -0.85  -0.01    0.84
# 10    -12.26  -7.99    4.26
# 11    -19.84 -17.47    2.37
# 12    -22.32 -21.12    1.20
