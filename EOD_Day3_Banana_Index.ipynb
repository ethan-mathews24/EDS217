# %% [markdown]
# # Day 3 EOD: The Banana Index
#
# Date: 09/02/2026

# %% [markdown]
# df[df['column'] > value]                                  # the filter pattern
#
#
# df.sort_values('column', ascending=False).head(n)         # the top-N pattern, whole table
#
#
# df['column'].sort_values(ascending=False).head(n)         # the top-N pattern, one column

# %%
import pandas as pd
url = 'https://github.com/TheEconomist/banana-index-data/releases/download/1.0/bananaindex.csv'
df = pd.read_csv(url, index_col='entity')

# %%
df = df.drop(['year', 'Banana values', 'type', 'Chart?', 'Unnamed: 16'], axis='columns')

# %% [markdown]
# ### Part 1: Get your bearings

# %%
df.shape
# Out:
# (160, 11)

# %% [markdown]
# #### 1. How many foods are in the dataset, and how many columns are left after the drop?
#
#     - There are 160 foods in the dataset since that is what we indexed

# %%
df.head()
# Out:
#                emissions_kg  emissions_1000kcal  emissions_100g_protein  \
# entity
# Ale                0.488690            0.317338                0.878525
# Almond butter      0.387011            0.067265                0.207599
# Almond milk        0.655888            2.222230               13.595512
# Almonds            0.602368            0.105029                0.328335
# Apple juice        0.458378            0.955184               29.152212
#
#                emissions_100g_fat  land_use_kg  land_use_1000kcal  \
# entity
# Ale                      2.424209     0.811485           0.601152
# Almond butter            0.079103     7.683045           1.296870
# Almond milk              4.057470     1.370106           2.675063
# Almonds                  0.119361     8.230927           1.423376
# Apple juice             19.754980     0.660629           1.382839
#
#                Land use per 100 grams of protein  \
# entity
# Ale                                     1.577687
# ...

# %% [markdown]
# #### 2. Display the first few rows. What do the three columns whose names begin with Bananas index contain?
#
#     - The three columns contain the kg, 1000 kcal, and 100g of protein.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, Ale to Yoghurt
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   emissions_kg                       160 non-null    float64
#  1   emissions_1000kcal                 160 non-null    float64
#  2   emissions_100g_protein             158 non-null    float64
#  3   emissions_100g_fat                 160 non-null    float64
#  4   land_use_kg                        160 non-null    float64
#  5   land_use_1000kcal                  160 non-null    float64
#  6   Land use per 100 grams of protein  158 non-null    float64
#  7   Land use per 100 grams of fat      160 non-null    float64
#  8   Bananas index (kg)                 160 non-null    float64
#  9   Bananas index (1000 kcalories)     160 non-null    float64
#  10  Bananas index (100g protein)       160 non-null    float64
# dtypes: float64(11)
# ...

# %% [markdown]
# #### 3. Run .info(). Two columns have missing values. Which, and how many?
#
#     - The columns 'emissions_100g_protein' and 'land use per 100 grams of protein' are both missing two recordings.

# %%
df.loc['Bananas', 'Bananas index (kg)']
# Out:
# 1.0

# %% [markdown]
# #### 4. What is the value of Bananas index (kg) for Bananas itself? Explain in a sentence why the number has to come out that way.
#
#     - The value is 1. The number came out that way because the index is emissions and when it is divided by the banana emisssion (1/1) it will equal 1.

# %% [markdown]
# ### Part 2: Three Rankings
